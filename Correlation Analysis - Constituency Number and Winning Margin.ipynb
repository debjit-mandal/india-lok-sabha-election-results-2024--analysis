# %% [markdown]
# # Correlation Analysis - Constituency Number and Winning Margin
#
# This analysis examines the correlation between constituency number and winning margin in the 2024 Lok Sabha Elections.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('data/election_results_2024.csv')
data['Margin'] = pd.to_numeric(data['Margin'], errors='coerce')

# %% [markdown]
# ## Correlation between results

# %%
correlation = data[['Const. No.', 'Margin']].corr()
correlation
# Out:
#             Const. No.    Margin
# Const. No.    1.000000 -0.142235
# Margin       -0.142235  1.000000

# %% [markdown]
# ## Visualization of Correlation

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Const. No.', y='Margin', data=data)
plt.title('Correlation between Constituency Number and Winning Margin')
plt.xlabel('Constituency Number')
plt.ylabel('Winning Margin')
plt.show()

# %% [markdown]
# ## Conclusion
# The above analysis provides insights into the relationship between constituency number and winning margin in the 2024 Lok Sabha Elections.
